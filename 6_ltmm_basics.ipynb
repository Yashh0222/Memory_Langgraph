# %%
from langgraph.store.memory import InMemoryStore

# %%
# creating a store
store = InMemoryStore()

# %%
# creating a namespace
namespace = ("user", "u1")

# %% [markdown]
# Creating Memories

# %%
# Adding memories
store.put(namespace, "1", {"data": "User likes pizza"})
store.put(namespace, "2", {"data": "User prefers dark mode"})

# %%
# another namespace
namespace2 = ("user", "u2")

# %%
# Add memories
store.put(namespace2, "1", {"data": "User likes pasta"})
store.put(namespace2, "2", {"data": "User prefers grid style navigation"})

# %% [markdown]
# Retrieving Memories

# %%
# store.get(namespace, key)
store.get(namespace2, "2")
# Out:
# Item(namespace=['user', 'u2'], key='2', value={'data': 'User prefers grid style navigation'}, created_at='2026-07-31T05:41:31.859653+00:00', updated_at='2026-07-31T05:41:31.859653+00:00')

# %% [markdown]
# Retrieving all Memories

# %%
items = store.search(namespace2)

for item in items:
    print(item.value)
# Out:
# {'data': 'User likes pasta'}
# {'data': 'User prefers grid style navigation'}

# %% [markdown]
# Semantic Search

# %%
# %pip install langchain-huggingface
# %pip install sentence-transformers
# Out:
# Collecting langchain-huggingface
#   Using cached langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Collecting huggingface-hub<2.0.0,>=0.33.4 (from langchain-huggingface)
#   Downloading huggingface_hub-1.26.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-huggingface) (1.5.2)
# Collecting tokenizers<1.0.0,>=0.19.1 (from langchain-huggingface)
#   Using cached tokenizers-0.23.1-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface)
#   Downloading filelock-3.32.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface)
#   Using cached fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface)
#   Using cached hf_xet-1.5.2-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\yash\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Collecting tqdm>=4.42.1 (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface)
#   Using cached tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\yash\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.10.12)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.17.0)
# Requirement already satisfied: colorama in c:\users\yash\appdata\roaming\python\python312\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.14.2)
# Requirement already satisfied: certifi in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.7.0)
# Using cached langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Downloading huggingface_hub-1.26.0-py3-none-any.whl (780 kB)
#    ---------------------------------------- 0.0/780.4 kB ? eta -:--:--
#    ---------------------------------------- 780.4/780.4 kB 5.5 MB/s eta 0:00:00
# Using cached tokenizers-0.23.1-cp310-abi3-win_amd64.whl (2.8 MB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Downloading filelock-3.32.2-py3-none-any.whl (98 kB)
# Using cached fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Using cached hf_xet-1.5.2-cp38-abi3-win_amd64.whl (4.0 MB)
# Using cached tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, hf-xet, fsspec, filelock, click, huggingface-hub, tokenizers, langchain-huggingface
# Successfully installed click-8.4.2 filelock-3.32.2 fsspec-2026.7.0 hf-xet-1.5.2 huggingface-hub-1.26.0 langchain-huggingface-1.2.2 tokenizers-0.23.1 tqdm-4.70.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.6.1-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-5.14.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.26.0)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.13.0-cp312-cp312-win_amd64.whl.metadata (39 kB)
# Collecting numpy>=1.20.0 (from sentence-transformers)
#   Using cached numpy-2.5.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting scikit-learn>=0.22.0 (from sentence-transformers)
#   Using cached scikit_learn-1.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy>=1.0.0 (from sentence-transformers)
#   Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\yash\appdata\roaming\python\python312\site-packages (from sentence-transformers) (4.16.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.70.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\yash\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (6.0.3)
# Collecting joblib>=1.4.0 (from scikit-learn>=0.22.0->sentence-transformers)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn>=0.22.0->sentence-transformers)
#   Using cached narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn>=0.22.0->sentence-transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting setuptools>=77.0.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\yash\appdata\roaming\python\python312\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Collecting regex>=2025.10.22 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached regex-2026.7.19-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached typer-0.27.0-py3-none-any.whl.metadata (15 kB)
# Collecting safetensors>=0.8.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.14.2)
# Requirement already satisfied: certifi in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\yash\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached sentence_transformers-5.6.1-py3-none-any.whl (596 kB)
# Using cached numpy-2.5.1-cp312-cp312-win_amd64.whl (12.4 MB)
# Using cached scikit_learn-1.9.0-cp312-cp312-win_amd64.whl (8.2 MB)
# Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl (36.6 MB)
# Using cached torch-2.13.0-cp312-cp312-win_amd64.whl (122.1 MB)
# Using cached transformers-5.14.1-py3-none-any.whl (11.6 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached narwhals-2.24.0-py3-none-any.whl (461 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached regex-2026.7.19-cp312-cp312-win_amd64.whl (277 kB)
# Using cached safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached typer-0.27.0-py3-none-any.whl (122 kB)
# Using cached annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, shellingham, setuptools, safetensors, regex, numpy, networkx, narwhals, mdurl, MarkupSafe, joblib, annotated-doc, scipy, markdown-it-py, jinja2, torch, scikit-learn, rich, typer, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.23.1
#     Uninstalling tokenizers-0.23.1:
#       Successfully uninstalled tokenizers-0.23.1
# Successfully installed MarkupSafe-3.0.3 annotated-doc-0.0.5 jinja2-3.1.6 joblib-1.5.3 markdown-it-py-4.2.0 mdurl-0.1.2 mpmath-1.3.0 narwhals-2.24.0 networkx-3.6.1 numpy-2.5.1 regex-2026.7.19 rich-15.0.0 safetensors-0.8.0 scikit-learn-1.9.0 scipy-1.18.0 sentence-transformers-5.6.1 setuptools-83.0.0 shellingham-1.5.4 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.2 torch-2.13.0 transformers-5.14.1 typer-0.27.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from dotenv import load_dotenv

load_dotenv()

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1805.87it/s]

# %%
store = InMemoryStore(index={'embed': embedding_model, 'dims':1536})

# %%
namespace = ('users', 'u1')

# %%
store.put(namespace, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace, "2", {"data": "User likes examples in Python"})
store.put(namespace, "3", {"data": "User usually works late at night"})
store.put(namespace, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items = store.search(namespace, query="what is the user currently learning", limit=1)

for item in items:
    print(item.value)
# Out:
# {'data': 'User is learning machine learning'}

# %%
items = store.search(namespace, query="what are user's preferences", limit=3)

for item in items:
    print(item.value)
# Out:
# {'data': 'User prefers dark mode in applications'}
# {'data': 'User likes examples in Python'}
# {'data': 'User prefers bullet points over paragraphs'}
